# %%
import os
import matplotlib.pyplot as plt
import numpy as np

import matplotlib

font = {'family': 'Arial', 'weight': 'normal', 'size': 14}
matplotlib.rc('font', **font)
LineWidth = 3

# %%
def plot_graph(bpp, psnr, fig_name=""):
    ours, = plt.plot(bpp, psnr, "k-o", linewidth=LineWidth, label='Proposed-Haar')

    # H.264 very fast setting.
    bpp = [0.008, 0.01431713, 0.019554398, 0.025353009, 0.041417824, 0.050, 0.10747685185185185]
    psnr = [36.84, 37.25, 37.47, 37.74, 38.25, 38.450, 39.034036367592854]
    h264, = plt.plot(bpp, psnr, "m--s", linewidth=LineWidth, label='H.264')

    bpp = [0.008, 0.012702546, 0.019392361, 0.025052083, 0.042853009, 0.050422453703703705, 0.10743634259259259]
    psnr = [37.63, 37.95, 38.23, 38.47, 38.80, 38.88, 39.34881156032801]
    h265, = plt.plot(bpp, psnr, "r--v", linewidth=LineWidth, label='H.265')

    plt.legend(handles=[h264, h265, ours], loc=4)
    plt.grid()
    plt.xlabel('BPP')
    plt.ylabel('PSNR(dB)')
    plt.title('')
    if fig_name != "":
        plt.savefig(fig_name, format='eps', dpi=600, bbox_inches='tight')

# %%
bpp = [0.008599537, 0.016753472, 0.042980324, 0.051]
psnr = [38.34, 39.39, 39.19, 41.13]
plot_graph(bpp, psnr, "encoderCom.eps")
# Out:
# findfont: Font family ['Arial'] not found. Falling back to DejaVu Sans.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
# 600 epocs with 100 for each

bpp = [0.01708912037037037,0.028119212962962964,0.039155092592592596,0.04884259259259259]
psnr  = [36.59149636623964, 37.26612184335303, 37.700065801709215 , 37.82092460584036]

plot_graph(bpp, psnr, "encoderCom600eps_100step.eps")
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
# 700 epocs with 200 for each
psnr = [37.010536430258554, 37.845215806154556 ,38.45107393645732, 40.01848739363824 , 38.83272494757646 ]
bpp = [0.014554398148148148, 0.023240740740740742, 0.03546875, 0.038871527777777776, 0.06010416666666667]

plot_graph(bpp, psnr, "encoderCom700eps_200step.eps")
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
# 10 epocs with 5000 for each
psnr =[34.26529791026975, 34.74531185606952, 35.043722140481876 , 36.924784417833806 ,  36.11658894786193 ]
bpp = [0.002476851851851852, 0.0040104166666666665, 0.0061805555555555555,0.004392361111111111, 0.017673611111111112]
plot_graph(bpp, psnr, "encoderCom10eps_5000step.eps")
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
psnr =[38.98687920576718 ,37.48376529958876 ,37.64011589737207 ,35.86676043184944 ,36.695214784876825 ]
bpp = [0.021388888888888888, 0.026140046296296297, 0.007581018518518518, 0.010092592592592592, 0.002679398148148148]
plot_graph(bpp, psnr, "encoderCom12eps_6000step_big_8192.eps")
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
psnr = [38.99991980310481 , 37.50672056042535, 37.649821895777094 , 35.848933564290206 , 36.695193114730024  ,34.54284907937003   ]
bpp = [0.02134837962962963, 0.025891203703703704, 0.007598379629629629, 0.010150462962962964, 0.002679398148148148, 0.004166666666666667]
plot_graph(bpp, psnr, "encoderCom.eps")
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
psnr = [39.858536050965135, 40.081576660625515 , 38.63873664542871, 38.370715467251415, 36.84136329337268, 37.01873485260242, 36.896056862258, 34.590923756067085]
bpp = [0.08355324074074075, 0.03336226851851852, 0.037141203703703704, 0.012175925925925925, 0.014861111111111111, 0.004137731481481482, 0.0025810185185185185, 0.0038599537037037036]
plot_graph(bpp, psnr, "encoderCom.eps")
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
psnr = [ 40.64930483510711 ,39.582951273704765 ,37.772609498763494 , 35.86185227190701, 34.533759399714484   ]
bpp = [ 0.10469328703703704, 0.05516782407407408, 0.023287037037037037, 0.009137731481481481, 0.0037962962962962963 ]
plot_graph(bpp, psnr, "Model_jump_mul_4_start_256.eps")
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
